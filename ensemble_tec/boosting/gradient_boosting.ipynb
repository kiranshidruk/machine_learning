# %%
# It is a sequencial stage wise addition algorithm

# %%
# For regression model, first models will always give mean value of output for all the points.
# Loss function is used to calculate this model accuracy/ how good model is. So that it will tell next model.
#  loss function : res = actual - predicted (pseudo-residual)

#  now next model is trained on input and the "res" calcualted by loss function as output.
#  So this model is predicted how accuratly checking wrongly predicted values by model1
#  it is proved decision trees works good here, so we are going to use decision trees
#  lets say output is actually two 3 for one of the inputs values. and model 1 is predicted as 4.8 because it is a mean value. 
#  then the difference between this values is "res1" is -1.8. 
#  model two will take "res1" as target now and  lets say by using decision trees it has predicted it to be -1.8
#  now in case we have only two models lets add the ouputs and check, so 4.8(m1) + -1.8(m2) = 3
#  thats the simpler explation for how gradient boosting works.
#  But this seems to be case of overfitting, so the learning rate comes into picture. for every model output we add some learning rate and as we increases number of model we will get there at our output.


#  simialar process of choosing loss function and calculating target goes on.

# %%
# Adaboosting vs Gradient Boosting

# decision stumps: tress which has max depth = 1 in adaboosting
#  max leaf_nodes : max leaf nodes 8-32  for gradient boosting

# weights for models are different in case of adaboosting based on model importance.
# Learning rate for gradient boosting all models are same.

# %%
# The output of first model is mean because we are using least square loss function

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Classification
# In case of classification the only change is instead of using MSE, we will use loss log function as loss function.function 
# also instead of simple mean as first model, here we use simple models with log(odds)--> log(no of 1/no of 0)
#  then we need to take probability of pred_log.
#  As it is probability we can set threshold for classification here in first stage.
#  for the next models we need to calcualte log(odd) using different formulae for every leaf node and based on that we calculate res2 for pred(log_odds) and to calculate resudial we calculate prob(log_odds)

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)
