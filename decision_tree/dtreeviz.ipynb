# %%
# !pip install dtreeviz
# Out:
# Requirement already satisfied: dtreeviz in /opt/anaconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: graphviz>=0.9 in /opt/anaconda3/lib/python3.12/site-packages (from dtreeviz) (0.20.3)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (from dtreeviz) (2.2.2)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from dtreeviz) (1.26.4)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.12/site-packages (from dtreeviz) (1.5.1)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.12/site-packages (from dtreeviz) (3.9.2)
# Requirement already satisfied: colour in /opt/anaconda3/lib/python3.12/site-packages (from dtreeviz) (0.1.5)
# Requirement already satisfied: pytest in /opt/anaconda3/lib/python3.12/site-packages (from dtreeviz) (7.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->dtreeviz) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->dtreeviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->dtreeviz) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->dtreeviz) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->dtreeviz) (24.1)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->dtreeviz) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->dtreeviz) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->dtreeviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->dtreeviz) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->dtreeviz) (2023.3)
# Requirement already satisfied: iniconfig in /opt/anaconda3/lib/python3.12/site-packages (from pytest->dtreeviz) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /opt/anaconda3/lib/python3.12/site-packages (from pytest->dtreeviz) (1.0.0)
# Requirement already satisfied: scipy>=1.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn->dtreeviz) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn->dtreeviz) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn->dtreeviz) (3.5.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.16.0)

# %%
import graphviz.backend as be
from sklearn import *
from dtreeviz import *
from sklearn.datasets import load_iris
from IPython.display import Image, display_svg, SVG
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
clas = tree.DecisionTreeClassifier()
iris = load_iris()

X = pd.DataFrame(iris.data, columns=iris.feature_names)
y = pd.Series(iris.target)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)


clas.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree

plot_tree(clas)
# Out:
# [Text(0.3076923076923077, 0.9285714285714286, 'x[3] <= 0.8\ngini = 0.666\nsamples = 112\nvalue = [35, 39, 38]'),
#  Text(0.23076923076923078, 0.7857142857142857, 'gini = 0.0\nsamples = 35\nvalue = [35, 0, 0]'),
#  Text(0.2692307692307693, 0.8571428571428572, 'True  '),
#  Text(0.38461538461538464, 0.7857142857142857, 'x[2] <= 4.75\ngini = 0.5\nsamples = 77\nvalue = [0.0, 39.0, 38.0]'),
#  Text(0.34615384615384615, 0.8571428571428572, '  False'),
#  Text(0.15384615384615385, 0.6428571428571429, 'x[3] <= 1.65\ngini = 0.056\nsamples = 35\nvalue = [0, 34, 1]'),
#  Text(0.07692307692307693, 0.5, 'gini = 0.0\nsamples = 34\nvalue = [0, 34, 0]'),
#  Text(0.23076923076923078, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6153846153846154, 0.6428571428571429, 'x[3] <= 1.75\ngini = 0.21\nsamples = 42\nvalue = [0, 5, 37]'),
#  Text(0.38461538461538464, 0.5, 'x[2] <= 4.95\ngini = 0.5\nsamples = 8\nvalue = [0, 4, 4]'),
#  Text(0.3076923076923077, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.46153846153846156, 0.35714285714285715, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.21428571428571427, 'x[0] <= 6.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.46153846153846156, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.6153846153846154, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8461538461538461, 0.5, 'x[2] <= 4.85\ngini = 0.057\nsamples = 34\nvalue = [0, 1, 33]'),
#  Text(0.7692307692307693, 0.35714285714285715, 'x[1] <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.6923076923076923, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.8461538461538461, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9230769230769231, 0.35714285714285715, 'gini = 0.0\nsamples = 31\nvalue = [0, 0, 31]')]

# %%
# !pip install dtreeviz
# Out:
# Requirement already satisfied: dtreeviz in /opt/anaconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: graphviz>=0.9 in /opt/anaconda3/lib/python3.12/site-packages (from dtreeviz) (0.20.3)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (from dtreeviz) (2.2.2)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from dtreeviz) (1.26.4)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.12/site-packages (from dtreeviz) (1.5.1)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.12/site-packages (from dtreeviz) (3.9.2)
# Requirement already satisfied: colour in /opt/anaconda3/lib/python3.12/site-packages (from dtreeviz) (0.1.5)
# Requirement already satisfied: pytest in /opt/anaconda3/lib/python3.12/site-packages (from dtreeviz) (7.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->dtreeviz) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->dtreeviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->dtreeviz) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->dtreeviz) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->dtreeviz) (24.1)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->dtreeviz) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->dtreeviz) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->dtreeviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->dtreeviz) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->dtreeviz) (2023.3)
# Requirement already satisfied: iniconfig in /opt/anaconda3/lib/python3.12/site-packages (from pytest->dtreeviz) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /opt/anaconda3/lib/python3.12/site-packages (from pytest->dtreeviz) (1.0.0)
# Requirement already satisfied: scipy>=1.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn->dtreeviz) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn->dtreeviz) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn->dtreeviz) (3.5.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.16.0)

# %%
# Visualize the tree

from dtreeviz import model
viz = model(
    clas,
    X_train,
    y_train,
    feature_names=iris.feature_names,
    target_name="species",
    class_names=list(iris.target_names),
)
viz.view()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names

# %%
# !brew install graphviz
# Out:
# ==> Auto-updating Homebrew...
# Adjust how often this is run with HOMEBREW_AUTO_UPDATE_SECS or disable with
# HOMEBREW_NO_AUTO_UPDATE. Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# ==> Downloading https://ghcr.io/v2/homebrew/portable-ruby/portable-ruby/blobs/sha256:7645e2d653a335798030f6502e7834dfdbeeec5629429a1a34da5dbb2c57d63e
# ######################################################################### 100.0%                                           33.2%
# ==> Pouring portable-ruby-3.3.8.arm64_big_sur.bottle.tar.gz
# ==> Auto-updated Homebrew!
# Updated 2 taps (homebrew/core and homebrew/cask).
# ==> New Formulae
# add-determinism            intermodal                 technitium-library
# api-linter                 kubernetes-cli@1.32        tfcmt
# brename                    nip4                       tfmv
# buffrs                     opkssh                     tfsort
# cargo-shear                otterdog                   tsui
# dblab                      prog8                      twitch-cli
# dockerfmt                  protoc-gen-doc             uhubctl
# erlfmt                     pyp                        wrkflw
# fedify                     sacad                      xtl
# hub-tool                   technitium-dns
# ==> New Casks
# antinote                   font-ancizar-serif         ndi-tools
# comfyui                    font-exile                 notion-mail
# companion                  font-huninn                opencloud
# companion-satellite        font-kumar-one-outline     ovice
# companion@beta             font-libertinus-math       profit
# dante-controller           font-libertinus-mono       realvnc-connect
# dante-via                  font-m-plus-rounded-1c     viables
# deepchat                   highlight                  vimy
# excire-foto                ijhttp                     warp@preview
# font-ancizar-sans          liviable
#
# You have 20 outdated formulae installed.
#
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphviz/manifests/12.2.1
# ######################################################################### 100.0%
# ==> Fetching dependencies for graphviz: libavif, gd, jasper, netpbm, gts, gdk-pixbuf, librsvg, m4 and libtool
# ==> Downloading https://ghcr.io/v2/homebrew/core/libavif/manifests/1.2.1
# ######################################################################### 100.0%
# ==> Fetching libavif
# ==> Downloading https://ghcr.io/v2/homebrew/core/libavif/blobs/sha256:c82c77f895
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gd/manifests/2.3.3_6
# ######################################################################### 100.0%
# ==> Fetching gd
# ==> Downloading https://ghcr.io/v2/homebrew/core/gd/blobs/sha256:e278f6f79e6ac00
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jasper/manifests/4.2.5
# ######################################################################### 100.0%
# ==> Fetching jasper
# ==> Downloading https://ghcr.io/v2/homebrew/core/jasper/blobs/sha256:466fe76a53e
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/netpbm/manifests/11.02.15
# ######################################################################### 100.0%
# ==> Fetching netpbm
# ==> Downloading https://ghcr.io/v2/homebrew/core/netpbm/blobs/sha256:29c8b6945df
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gts/manifests/0.7.6_3
# ######################################################################### 100.0%
# ==> Fetching gts
# ==> Downloading https://ghcr.io/v2/homebrew/core/gts/blobs/sha256:45ce1fc7fc4da5
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gdk-pixbuf/manifests/2.42.12_1
# ######################################################################### 100.0%
# ==> Fetching gdk-pixbuf
# ==> Downloading https://ghcr.io/v2/homebrew/core/gdk-pixbuf/blobs/sha256:c703ce1
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/librsvg/manifests/2.60.0
# ######################################################################### 100.0%
# ==> Fetching librsvg
# ==> Downloading https://ghcr.io/v2/homebrew/core/librsvg/blobs/sha256:a98fcd2388
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/m4/manifests/1.4.19
# ######################################################################### 100.0%
# ==> Fetching m4
# ==> Downloading https://ghcr.io/v2/homebrew/core/m4/blobs/sha256:f42d89db519a07d
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtool/manifests/2.5.4
# ######################################################################### 100.0%
# ==> Fetching libtool
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtool/blobs/sha256:b78cea0747
# ######################################################################### 100.0%
# ==> Fetching graphviz
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphviz/blobs/sha256:067aecda0
# ######################################################################### 100.0%
# ==> Installing dependencies for graphviz: libavif, gd, jasper, netpbm, gts, gdk-pixbuf, librsvg, m4 and libtool
# ==> Installing graphviz dependency: libavif
# ==> Downloading https://ghcr.io/v2/homebrew/core/libavif/manifests/1.2.1
# Already downloaded: /Users/kiranshidruk/Library/Caches/Homebrew/downloads/a3880a25438e74c798bd1fc9305af44be3f3680e04c511626de04a030cf1838d--libavif-1.2.1.bottle_manifest.json
# ==> Pouring libavif--1.2.1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libavif/1.2.1: 22 files, 990.5KB
# ==> Installing graphviz dependency: gd
# ==> Downloading https://ghcr.io/v2/homebrew/core/gd/manifests/2.3.3_6
# Already downloaded: /Users/kiranshidruk/Library/Caches/Homebrew/downloads/1f63d9efd8c74faa4477bd8b8a3970abd38e51230ed052918bb6f3715aab8b61--gd-2.3.3_6.bottle_manifest.json
# ==> Pouring gd--2.3.3_6.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/gd/2.3.3_6: 34 files, 1.5MB
# ==> Installing graphviz dependency: jasper
# ==> Downloading https://ghcr.io/v2/homebrew/core/jasper/manifests/4.2.5
# Already downloaded: /Users/kiranshidruk/Library/Caches/Homebrew/downloads/0b7879dee43d75b41e26cd2680fb480d314374076cdd50feb7f4ed998ab38964--jasper-4.2.5.bottle_manifest.json
# ==> Pouring jasper--4.2.5.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/jasper/4.2.5: 45 files, 1.6MB
# ==> Installing graphviz dependency: netpbm
# ==> Downloading https://ghcr.io/v2/homebrew/core/netpbm/manifests/11.02.15
# Already downloaded: /Users/kiranshidruk/Library/Caches/Homebrew/downloads/1f07bc7e12b9b9121074664f637cda7814c45c9bb815eb4ee204485abe39ed94--netpbm-11.02.15.bottle_manifest.json
# ==> Pouring netpbm--11.02.15.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/netpbm/11.02.15: 825 files, 19.5MB
# ==> Installing graphviz dependency: gts
# ==> Downloading https://ghcr.io/v2/homebrew/core/gts/manifests/0.7.6_3
# Already downloaded: /Users/kiranshidruk/Library/Caches/Homebrew/downloads/0cb7519523b42ff855917c33218c1ef771e3060080fea895de59eb848c833cd1--gts-0.7.6_3.bottle_manifest.json
# ==> Pouring gts--0.7.6_3.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/gts/0.7.6_3: 27 files, 1.6MB
# ==> Installing graphviz dependency: gdk-pixbuf
# ==> Downloading https://ghcr.io/v2/homebrew/core/gdk-pixbuf/manifests/2.42.12_1
# Already downloaded: /Users/kiranshidruk/Library/Caches/Homebrew/downloads/2eeb910ea69bc28d9dc0b3b121819ff59ea92fa20bab68c59b6a7a7d5af0708b--gdk-pixbuf-2.42.12_1.bottle_manifest.json
# ==> Pouring gdk-pixbuf--2.42.12_1.arm64_sonoma.bottle.tar.gz
# ==> /opt/homebrew/Cellar/gdk-pixbuf/2.42.12_1/bin/gdk-pixbuf-query-loaders --upd
# 🍺  /opt/homebrew/Cellar/gdk-pixbuf/2.42.12_1: 152 files, 4.0MB
# ==> Installing graphviz dependency: librsvg
# ==> Downloading https://ghcr.io/v2/homebrew/core/librsvg/manifests/2.60.0
# Already downloaded: /Users/kiranshidruk/Library/Caches/Homebrew/downloads/564e4408fe6b5ea163af9c5e0e6eca1822b848e61f8c28214962d5a5218b801a--librsvg-2.60.0.bottle_manifest.json
# ==> Pouring librsvg--2.60.0.arm64_sonoma.bottle.tar.gz
# ==> /opt/homebrew/opt/gdk-pixbuf/bin/gdk-pixbuf-query-loaders --update-cache
# 🍺  /opt/homebrew/Cellar/librsvg/2.60.0: 21 files, 21.2MB
# ==> Installing graphviz dependency: m4
# ==> Downloading https://ghcr.io/v2/homebrew/core/m4/manifests/1.4.19
# Already downloaded: /Users/kiranshidruk/Library/Caches/Homebrew/downloads/5b2a7f715487b7377e409e8ca58569040cd89f33859f691210c58d94410fd33b--m4-1.4.19.bottle_manifest.json
# ==> Pouring m4--1.4.19.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/m4/1.4.19: 14 files, 728.7KB
# ==> Installing graphviz dependency: libtool
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtool/manifests/2.5.4
# Already downloaded: /Users/kiranshidruk/Library/Caches/Homebrew/downloads/caf68ff95c648186998b530b6be93ecb50b17ff8e55d0531c81a5b9456cf2887--libtool-2.5.4.bottle_manifest.json
# ==> Pouring libtool--2.5.4.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libtool/2.5.4: 76 files, 4.0MB
# ==> Installing graphviz
# ==> Pouring graphviz--12.2.1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/graphviz/12.2.1: 283 files, 7.8MB
# ==> Running `brew cleanup graphviz`...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
